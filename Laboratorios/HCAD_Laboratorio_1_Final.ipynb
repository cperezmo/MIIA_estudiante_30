# %% [markdown]
# ## Contexto: exploración del potencial para asignar becas Uniandes
# La Universidad de los Andes se ha caracterizado por su compromiso con la generación de impacto en la sociedad a través de diferentes programas de becas. Programas como Quiero Estudiar, o Ser Pilo Paga, entre otros, han sido revolucionarios, al permitir que estudiantes de bajos recursos puedan acceder a una de las universidades privadas más importantes del país.
#
# Actualmente, la Universidad quiere evaluar el potencial impacto que tendrían algunos programas de *acción afirmativa* para asignación de becas, con base en información demográfica que ha obtenido a través de encuestas. Se cuenta con información respecto a la edad, género, estado civil, estrato socio-económico, región de proveniencia, desempeño académico y nivel de escolaridad de las personas que han respondido encuestas. Los encargados de diseñar el programa saben que utilizar criterios basados en este tipo de variables es un tema sensible, pero es necesario si se quieren focalizar las oportunidades en poblaciones menos representadas.
#
# El objetivo de este laboratorio es crear una herramienta computacional que permita a un tomador de decisiones explorar qué efecto podría tener el uso de diferentes reglas para seleccionar la población que sería beneficiaria de las becas. Puntualmente, se espera que, dadas unas reglas de selección (ej.: pertenecer a cierta región, rango de edad, etc.), la herramienta ofrezca información sobre la población potencialmente beneficiada, de forma que exista un sustento al momento de definir las reglas de selección.

# %% [markdown]
# <img src="Archivos/miia.jpg" width=800x>
#
# # Laboratorio 1
#
# ## Desarrollo de una herramienta analítica usando solo Python
#
# Este laboratorio busca evaluar las habilidades relacionadas con la primera parte del curso, correspondiente a las primeras tres semanas. Este enunciado estará disponible desde la semana 2 y deberá entregarse al final de la semana 4 en el enlace correspondiente. Su desarrollo corresponde al 30% de la calificación total del curso.
#
# Esta actividad responde directamente al segundo objetivo del curso:
# * Implementar una herramienta analítica que permita responder una pregunta de negocio para un problema sencillo de analítica de datos, utilizando únicamente algorítmica básica en Python.
#
# Al desarrollar este laboratorio pondrás a prueba tus habilidades para:
# 1. Leer datos desde archivos.
# 2. Almacenar datos en  estructuras de Python.
# 3. Crear y llamar funciones correctamente.
# 4. Implementar condicionales diferenciando *if*, *elif* y *else*
# 5. Implementar ciclos diferenciando el propósito de *for* y *while*
# 6. Importar paquetes y utilizar sus funciones.
#
# **NOTAS:**
# - Te recomendamos leer por completo el enunciado del laboratorio antes de comenzar, de forma que tengas claro el propósito completo de la actividad, y puedas desarrollar tu solución apuntando a él desde el comienzo.

# %% [markdown]
# ## 1. Obtención e inspección de archivos
#
# Los datos de encuestas fueron obtenidos como parte de un trabajo de campo, y por limitaciones tecnológicas, solo se cuenta con la información en archivos de texto plano. Cada archivo corresponde a una de las variables antes mencionadas y se puede garantizar que todos relacionan a las personas encuestadas en el mismo orden (i.e., la primera línea de todos los archivos corresponde a datos de la primera persona encuestada, la segunda línea a la segunda persona, etc.).
#
# Los archivos con los que se cuenta son:
# * *edades.txt*: un archivo ordenado con las edades de cada persona de la población encuestada
# * *género.txt*: un archivo ordenado con el género de cada persona de la población encuestada
# * *estado_civil.txt*: un archivo ordenado con el estado civil de cada persona de la población encuestada
# * *escolaridad.txt*: un archivo ordenado con el nivel de escolaridad de cada persona de la población encuestada
# * *estrato.txt*: un archivo ordenado con el estrato socio-económico de cada persona de la población encuestada
# * *region.txt*: un archivo ordenado con la región de proveniencia de cada persona de la población encuestada

# %% [markdown]
# **Misión 1**
#
# Poner en variables de Python la información que está en los archivos listados arriba.
#
# * *Versión base*: escribe línea a línea el código necesario para poner en variables de Python la información de cada uno de los archivos.
#
# * *Milla extra*: escribe una función que sea capaz de hacer lo anterior para un archivo y úsala en un ciclo para automatizar la lectura de los diferentes archivos.

# %%
# código

a1 = open('edad.txt','r')
edades = a1.readlines()
edades_num = []
for i in edades:
  dato_int = int(i)
  edades_num.append(dato_int)

#print(edades_num)

a2 = open('genero.txt','r')
genero = a2.read()
#print(genero)

a3 = open('estado_civil.txt','r')
estado_civil = a3.read()

a4 = open('escolaridad.txt','r')
escolaridad = a4.read()

a5 = open('estrato.txt','r')
estado_civil = a5.read()

a6 = open('region.txt','r')
escolaridad = a6.read()

import pandas as pd

lista_nombres_archivos = ['edad.txt','genero.txt','estado_civil.txt','escolaridad.txt','estrato.txt','region.txt']

def automatizar_lectura(nombres_archivos):

  with open(nombres_archivos[0]) as f:
    text_list = f.readlines()

    indice = []
    for i in range(len(text_list)):
      indice.append(i)

    columnas = []
    for i in nombres_archivos:
      columnas.append(i)

    df = pd.DataFrame(index = indice, columns = columnas)

    for i in range(len(nombres_archivos)):
      with open(nombres_archivos[i]) as f:
        text_list = f.readlines()
        print("Datos 0-5 en "+str(nombres_archivos[i])+": "+str(text_list[0:5])+"\n")

      for j in range(len(text_list)):
        dato = text_list[j]
        df.iloc[j,i] = dato

    return df

df_datos = automatizar_lectura(lista_nombres_archivos)

print("")
print(df_datos)
# Out:
# Datos 0-5 en edad.txt: ['36\n', '66\n', '24\n', '55\n', '26\n']
#
# Datos 0-5 en genero.txt: ['masculino\n', 'masculino\n', 'femenino\n', 'masculino\n', 'otro\n']
#
# Datos 0-5 en estado_civil.txt: ['casada\n', 'divorciada\n', 'divorciada\n', 'casada\n', 'divorciada\n']
#
# Datos 0-5 en escolaridad.txt: ['Secundaria\n', 'Profesional\n', 'Secundaria\n', 'Secundaria\n', 'Secundaria\n']
#
# Datos 0-5 en estrato.txt: ['5\n', '1\n', '3\n', '3\n', '2\n']
#
# Datos 0-5 en region.txt: ['Andina\n', 'Andina\n', 'Pacifica\n', 'Pacifica\n', 'Orinoquia\n']
#
#
#     edad.txt    genero.txt estado_civil.txt escolaridad.txt estrato.txt  \
# 0       36\n   masculino\n         casada\n    Secundaria\n         5\n
# 1       66\n   masculino\n     divorciada\n   Profesional\n         1\n
# 2       24\n    femenino\n     divorciada\n    Secundaria\n         3\n
# 3       55\n   masculino\n         casada\n    Secundaria\n         3\n
# ...

# %% [markdown]
# **Misión 2**
#
# Reportar las principales características en los datos.
# * *Versión base*: utilizar métricas básicas como conteos o promedios por categorías en los datos.
# * *Milla extra*: utilizar visualizaciones simples como diagramas de barras, de pastel u otros.

# %%
# código

# importación de paquetes necesarios

import statistics as stats  # Librería para realizar calculos estadísticos
import matplotlib.pyplot as plt  # Librería para graficar


# función que calcula la mediana de una lista de datos numéricos

def calcular_mediana(datos):
  mediana = stats.median(datos)

  return mediana


# función que calcula la desviación de una lista de datos numéricos

def calcular_desv_est(datos):

  desv_est = stats.stdev(datos)

  return desv_est

#Milla_extra:

a6 = open('region.txt','r')
lista_region = a6.readlines()
print(lista_region)
no_Andina = 0
no_Amazonia = 0
no_Caribe = 0
no_Orinoquia = 0
no_Pacifica = 0

for i in range(len(lista_region)):
  lista_region[i] = lista_region[i].replace('\n',"")
  if lista_region[i] == 'Andina':
    no_Andina = no_Andina + 1
  if lista_region[i] == 'Amazonia':
    no_Amazonia = no_Amazonia + 1
  if lista_region[i] == 'Caribe':
    no_Caribe = no_Caribe + 1
  if lista_region[i] == 'Orinoquia':
    no_Orinoquia = no_Orinoquia + 1
  if lista_region[i] == 'Pacifica':
    no_Pacifica = no_Pacifica + 1

frecuencia_por_departamento = [no_Andina,no_Amazonia,no_Caribe,no_Orinoquia,no_Pacifica]
etiquetas = ['Andina','Amazonia','Caribe','Orinoquia','Pacifica']

plt.pie(frecuencia_por_departamento,labels = etiquetas,
        colors = ["Red","Green","Yellow","Blue","Purple"],
        shadow = True,
        startangle = 90,
        radius = 2)

plt.show()

import seaborn as sns

plt = sns.barplot(x = etiquetas, y = frecuencia_por_departamento)
plt.set(xlabel = "Región", ylabel = "Frecuencia")

  


'''
función que visualiza las características de una población dada
(nota que la variable 'poblacion' es local; podemos pasar cualquier población a la función)
'''
# Out:
# ['Andina\n', 'Andina\n', 'Pacifica\n', 'Pacifica\n', 'Orinoquia\n', 'Caribe\n', 'Amazonia\n', 'Andina\n', 'Caribe\n', 'Andina\n', 'Caribe\n', 'Pacifica\n', 'Caribe\n', 'Pacifica\n', 'Pacifica\n', 'Pacifica\n', 'Caribe\n', 'Caribe\n', 'Andina\n', 'Andina\n', 'Pacifica\n', 'Pacifica\n', 'Caribe\n', 'Caribe\n', 'Andina\n', 'Caribe\n', 'Andina\n', 'Caribe\n', 'Caribe\n', 'Andina\n', 'Caribe\n', 'Caribe\n', 'Caribe\n', 'Andina\n', 'Andina\n', 'Pacifica\n', 'Caribe\n', 'Caribe\n', 'Caribe\n', 'Orinoquia\n', 'Pacifica\n', 'Pacifica\n', 'Caribe\n', 'Pacifica\n', 'Orinoquia\n', 'Andina\n', 'Andina\n', 'Caribe\n', 'Caribe\n', 'Amazonia\n', 'Orinoquia\n', 'Caribe\n', 'Pacifica\n', 'Caribe\n', 'Pacifica\n', 'Pacifica\n', 'Caribe\n', 'Caribe\n', 'Orinoquia\n', 'Caribe\n', 'Caribe\n', 'Andina\n', 'Andina\n', 'Andina\n', 'Pacifica\n', 'Orinoquia\n', 'Pacifica\n', 'Pacifica\n', 'Pacifica\n', 'Pacifica\n', 'Caribe\n', 'Caribe\n', 'Caribe\n', 'Orinoquia\n', 'Andina\n', 'Andina\n', 'Pacifica\n', 'Carib
# ...

# %% [markdown]
# ## 2. Abordaje de la pregunta de negocio
#
# El comité encargado de diseñar el programa de becas ha tenido dificultades para llegar a acuerdos. Algunos piensan que el criterio principal de selección debería ser respecto a lo económico y académico, sin importar otras características personales, mientras que otros piensan que considerar estas características es, de hecho, parte del espíritu del programa.
#
# * El primer grupo sugiere que se deben tomar en orden ascendente los estratos y elegir, en cada uno de ellos, al 2% de personas con promedio académico superior en esa sub-población, hasta que se agoten las becas disponibles. En caso de quedar becas disponibles al final del proceso, se repite el mismo esquema, considerando que ya no se tienen en cuenta las personas que hayan sido elegidas en rondas anteriores.
#
# * El segundo grupo sugiere que los recibidores de becas deben estar igualmente distribuidos entre las diferentes regiones y generos, considerando, por supuesto, que para cada una de esas sub-poblaciones, las personas elegidas sean las de mejores promedios académicos.
#
# Dado que las diferencias entre estos grupos obedecen a su entendimiento particular del problema, el presidente del comité propone utilizar los datos disponibles de las encuestas, sugiriendo que se analice qué características tendría la población de elegidos bajo cada uno de los dos criterios expuestos.

# %% [markdown]
# **Misión 3**
#
# Defina la pregunta de negocio y la pregunta de *analytics* para esta situación.

# %%
# respuesta en texto (solo leeremos los primeros 300 caracteres de la respuesta)

#pregunta_negocio = '¿Cuales son los criterios más adecuados para la asignación de becas, ademas del promedio academico?

#pregunta_analytics = '¿Que caracteristicas tiene la población de elegidos bajo cada uno de los dos criterios expuestos?

# %% [markdown]
# **Misión 4**
#
# Desarrollar un algoritmo que permita conocer la población que sería becada según los criterios propuestos por el *primer grupo* mencionado arriba.

# %%
# código

#Criterio 1: Estratos (Orden ascendente)
#Criterio 2: De cada estrato el 2% de las personas con el mejor promedio académico

import pandas as pd
import math
import matplotlib.pyplot as plt

lista_nombres_archivos = ['edad.txt','genero.txt','estado_civil.txt','escolaridad.txt','estrato.txt','region.txt','promedio.txt']

def automatizar_lectura(nombres_archivos):
    
    with open(nombres_archivos[0]) as f:
        text_list = f.readlines()
    
    cantidad_datos = len(text_list)
    indice = []
    ID_persona = []

    for i in range(cantidad_datos):
      indice.append(i)
      ID_persona.append(i+1)
        
    columnas = []
    for i in range(len(nombres_archivos)):
      nombre_columna = nombres_archivos[i].replace(".txt","")
      columnas.append(nombre_columna)

    columnas.insert(0, "ID")
    columnas.append("Beca asignada")
    no_columnas = len(columnas)
    
    df = pd.DataFrame(index = indice, columns = columnas)
    

    for j in range(cantidad_datos):
      df.iloc[j,0] = ID_persona[j]
      df.iloc[j,no_columnas-1] = "NO"
    

    for i in range(len(nombres_archivos)):
        with open(nombres_archivos[i]) as f:
            text_list = f.readlines()
        
        for j in range(len(text_list)):
            dato = text_list[j]
            dato = dato.replace("\n","")
            df.iloc[j,i+1] = dato

    return df

df_datos = automatizar_lectura(lista_nombres_archivos)
df_datos = df_datos.sort_values('estrato')

becas_agotadas = False
no_becas_entregar = int(input("Por favor ingrese el número de becas a entregar: "))
no_becas_entregadas = 0

estrato1 = df_datos[:] [df_datos['estrato'] == '1']
estrato1 = estrato1.sort_values('promedio',ascending=False)

estrato2 = df_datos[:] [df_datos['estrato'] == '2']
estrato2 = estrato2.sort_values('promedio',ascending=False)

estrato3 = df_datos[:] [df_datos['estrato'] == '3']
estrato3 = estrato3.sort_values('promedio',ascending=False)

estrato4 = df_datos[:] [df_datos['estrato'] == '4']
estrato4 = estrato4.sort_values('promedio',ascending=False)

estrato5 = df_datos[:] [df_datos['estrato'] == '5']
estrato5 = estrato5.sort_values('promedio',ascending=False)
contador_recorrido = 1
print("")

while (becas_agotadas == False):
  print("Recorrido no."+str(contador_recorrido))
  no_becas_disponibles = no_becas_entregar - no_becas_entregadas
  poblacion_sin_beca = estrato1['Beca asignada'][estrato1['Beca asignada'] == 'NO'].count()
  dosPorc_pob_sin_beca = math.ceil(poblacion_sin_beca*0.02)
  print("")
  print("Estrato 1: ")
  print("No. becas disponibles: "+str(no_becas_disponibles))
  print("Población sin beca: "+str(poblacion_sin_beca))
  print("2% Población sin beca: "+str(dosPorc_pob_sin_beca))
  becas_entregadas_por_iteracion = 0
  if no_becas_disponibles >= dosPorc_pob_sin_beca:
    contador = 0
    for i in range(len(estrato1)):
      if (estrato1.iloc[i][8] == 'NO') and (contador<dosPorc_pob_sin_beca):
        estrato1.iloc[i][8] = 'SI'
        becas_entregadas_por_iteracion = becas_entregadas_por_iteracion + 1
        no_becas_entregadas = no_becas_entregadas + 1
        no_becas_disponibles = no_becas_entregar - no_becas_entregadas
        contador = contador + 1
        if no_becas_disponibles == 0:
          becas_agotadas = True
      else:
        pass
  else:
    if no_becas_disponibles > 0:
      for i in range(len(estrato1)):
        if (estrato1.iloc[i][8] == 'NO') and (no_becas_disponibles > 0):
          estrato1.iloc[i][8] = 'SI'
          becas_entregadas_por_iteracion = becas_entregadas_por_iteracion + 1
          no_becas_entregadas = no_becas_entregadas + 1
          no_becas_disponibles = no_becas_entregar - no_becas_entregadas
          if no_becas_disponibles == 0:
            becas_agotadas = True
          else:
            pass
  print("Becas entregas en esta iteración: "+str(becas_entregadas_por_iteracion))
  print("Total becas entregadas: "+str(no_becas_entregadas))
  print("")
  becas_entregadas_por_iteracion = 0

  poblacion_sin_beca = estrato2['Beca asignada'][estrato2['Beca asignada'] == 'NO'].count()
  dosPorc_pob_sin_beca = math.ceil(poblacion_sin_beca*0.02)
  print("Estrato 2: ")
  print("No. becas disponibles: "+str(no_becas_disponibles))
  print("Población sin beca: "+str(poblacion_sin_beca))
  print("2% Población sin beca: "+str(dosPorc_pob_sin_beca))
  if no_becas_disponibles >= dosPorc_pob_sin_beca:
    contador = 0
    for i in range(len(estrato2)):
      if (estrato2.iloc[i][8] == 'NO') and (contador<dosPorc_pob_sin_beca):
        estrato2.iloc[i][8] = 'SI'
        becas_entregadas_por_iteracion = becas_entregadas_por_iteracion + 1
        no_becas_entregadas = no_becas_entregadas + 1
        no_becas_disponibles = no_becas_entregar - no_becas_entregadas
        contador = contador + 1
        if no_becas_disponibles == 0:
          becas_agotadas = True
      else:
        pass
  else:
    if no_becas_disponibles > 0:
      for i in range(len(estrato2)):
        if (estrato2.iloc[i][8] == 'NO') and (no_becas_disponibles > 0):
          estrato2.iloc[i][8] = 'SI'
          becas_entregadas_por_iteracion = becas_entregadas_por_iteracion + 1
          no_becas_entregadas = no_becas_entregadas + 1
          no_becas_disponibles = no_becas_entregar - no_becas_entregadas
          if no_becas_disponibles == 0:
            becas_agotadas = True
          else:
            pass
  print("Becas entregas en esta iteración: "+str(becas_entregadas_por_iteracion))
  print("Total becas entregadas: "+str(no_becas_entregadas))
  print("")

  poblacion_sin_beca = estrato3['Beca asignada'][estrato3['Beca asignada'] == 'NO'].count()
  dosPorc_pob_sin_beca = math.ceil(poblacion_sin_beca*0.02)
  print("Estrato 3: ")
  print("No. becas disponibles: "+str(no_becas_disponibles))
  print("Población sin beca: "+str(poblacion_sin_beca))
  print("2% Población sin beca: "+str(dosPorc_pob_sin_beca))
  becas_entregadas_por_iteracion = 0
  if no_becas_disponibles >= dosPorc_pob_sin_beca:
    contador = 0
    for i in range(len(estrato3)):
      if (estrato3.iloc[i][8] == 'NO') and (contador<dosPorc_pob_sin_beca):
        estrato3.iloc[i][8] = 'SI'
        becas_entregadas_por_iteracion = becas_entregadas_por_iteracion + 1
        no_becas_entregadas = no_becas_entregadas + 1
        no_becas_disponibles = no_becas_entregar - no_becas_entregadas
        contador = contador + 1
        if no_becas_disponibles == 0:
          becas_agotadas = True
      else:
        pass
  else:
    if no_becas_disponibles > 0:
      for i in range(len(estrato3)):
        if (estrato3.iloc[i][8] == 'NO') and (no_becas_disponibles > 0):
          estrato3.iloc[i][8] = 'SI'
          becas_entregadas_por_iteracion = becas_entregadas_por_iteracion + 1
          no_becas_entregadas = no_becas_entregadas + 1
          no_becas_disponibles = no_becas_entregar - no_becas_entregadas
          if no_becas_disponibles == 0:
            becas_agotadas = True
          else:
            pass
  print("Becas entregas en esta iteración: "+str(becas_entregadas_por_iteracion))
  print("Total becas entregadas: "+str(no_becas_entregadas))
  print("")

  becas_entregadas_por_iteracion = 0
  poblacion_sin_beca = estrato4['Beca asignada'][estrato4['Beca asignada'] == 'NO'].count()
  dosPorc_pob_sin_beca = math.ceil(poblacion_sin_beca*0.02)
  print("Estrato 4: ")
  print("No. becas disponibles: "+str(no_becas_disponibles))
  print("Población sin beca: "+str(poblacion_sin_beca))
  print("2% Población sin beca: "+str(dosPorc_pob_sin_beca))
  if no_becas_disponibles >= dosPorc_pob_sin_beca:
    contador = 0
    for i in range(len(estrato4)):
      if (estrato4.iloc[i][8] == 'NO') and (contador<dosPorc_pob_sin_beca):
        estrato4.iloc[i][8] = 'SI'
        becas_entregadas_por_iteracion = becas_entregadas_por_iteracion + 1
        no_becas_entregadas = no_becas_entregadas + 1
        no_becas_disponibles = no_becas_entregar - no_becas_entregadas
        contador = contador + 1
        if no_becas_disponibles == 0:
          becas_agotadas = True
      else:
        pass

  else:
    if no_becas_disponibles > 0:
      for i in range(len(estrato4)):
        if (estrato4.iloc[i][8] == 'NO') and (no_becas_disponibles > 0):
          estrato4.iloc[i][8] = 'SI'
          becas_entregadas_por_iteracion = becas_entregadas_por_iteracion + 1
          no_becas_entregadas = no_becas_entregadas + 1
          no_becas_disponibles = no_becas_entregar - no_becas_entregadas
          if no_becas_disponibles == 0:
            becas_agotadas = True
          else:
            pass
  print("Becas entregas en esta iteración: "+str(becas_entregadas_por_iteracion))
  print("Total becas entregadas: "+str(no_becas_entregadas))
  print("")

  becas_entregadas_por_iteracion = 0
  poblacion_sin_beca = estrato5['Beca asignada'][estrato5['Beca asignada'] == 'NO'].count()
  dosPorc_pob_sin_beca = math.ceil(poblacion_sin_beca*0.02)
  print("Estrato 5: ")
  print("No. becas disponibles: "+str(no_becas_disponibles))
  print("Población sin beca: "+str(poblacion_sin_beca))
  print("2% Población sin beca: "+str(dosPorc_pob_sin_beca))
  if no_becas_disponibles >= dosPorc_pob_sin_beca:
    contador = 0
    for i in range(len(estrato5)):
      if (estrato5.iloc[i][8] == 'NO') and (contador<dosPorc_pob_sin_beca):
        estrato5.iloc[i][8] = 'SI'
        becas_entregadas_por_iteracion = becas_entregadas_por_iteracion + 1
        no_becas_entregadas = no_becas_entregadas + 1
        no_becas_disponibles = no_becas_entregar - no_becas_entregadas
        contador = contador + 1
        if no_becas_disponibles == 0:
          becas_agotadas = True
      else:
        pass
  else:
    if no_becas_disponibles > 0:
      for i in range(len(estrato5)):
        if (estrato5.iloc[i][8] == 'NO') and (no_becas_disponibles > 0):
          estrato5.iloc[i][8] = 'SI'
          becas_entregadas_por_iteracion = becas_entregadas_por_iteracion + 1
          no_becas_entregadas = no_becas_entregadas + 1
          no_becas_disponibles = no_becas_entregar - no_becas_entregadas
          if no_becas_disponibles == 0:
            becas_agotadas = True
          else:
            pass
  print("Becas entregas en esta iteración: "+str(becas_entregadas_por_iteracion))
  print("Total becas entregadas: "+str(no_becas_entregadas))
  print("")

  contador_recorrido = contador_recorrido + 1

df_final_grupo_asignacion1 = pd.DataFrame()
df_final_grupo_asignacion1 = pd.concat([estrato1,estrato2,estrato3,estrato4,estrato5])
print("DataFrame final: ")
print(df_final_grupo_asignacion1)

pob_est1_con_beca = estrato1['Beca asignada'][estrato1['Beca asignada'] == 'SI'].count()
pob_est2_con_beca = estrato2['Beca asignada'][estrato2['Beca asignada'] == 'SI'].count()
pob_est3_con_beca = estrato3['Beca asignada'][estrato3['Beca asignada'] == 'SI'].count()
pob_est4_con_beca = estrato4['Beca asignada'][estrato4['Beca asignada'] == 'SI'].count()
pob_est5_con_beca = estrato5['Beca asignada'][estrato5['Beca asignada'] == 'SI'].count()

print("Total becas entregadas: "+str(no_becas_entregadas)+"\n")
print("Población Estrato 1: "+str(len(estrato1)))
print("Población Estrato 2: "+str(len(estrato2)))
print("Población Estrato 3: "+str(len(estrato3)))
print("Población Estrato 4: "+str(len(estrato4)))
print("Población Estrato 5: "+str(len(estrato5))+"\n")
print("Becas entregadas Población Estrato 1: "+str(pob_est1_con_beca))
print("Becas entregadas Población Estrato 2: "+str(pob_est2_con_beca))
print("Becas entregadas Población Estrato 3: "+str(pob_est3_con_beca))
print("Becas entregadas Población Estrato 4: "+str(pob_est4_con_beca))
print("Becas entregadas Población Estrato 5: "+str(pob_est5_con_beca))
print("")
print("No. veces recorrido de estratos: "+str(contador_recorrido))

etiquetas = ["Estrato 1","Estrato 2","Estrato 3","Estrato 4","Estrato 5"]

frec_estrato = [pob_est1_con_beca,pob_est2_con_beca,pob_est3_con_beca,pob_est4_con_beca,pob_est5_con_beca]

plt.pie(frec_estrato,labels = etiquetas,
        colors = ["Red","Green","Yellow","Blue","Purple"],
        shadow = True,
        startangle = 90,
        radius = 2)

plt.show()

# %% [markdown]
# **Misión 5**
#
# Desarrollar un algoritmo que permita conocer la población que sería becada según los criterios propuestos por el *segundo grupo* mencionado arriba.

# %%
# código

#El segundo grupo sugiere que los recibidores de becas deben estar igualmente distribuidos entre
#las diferentes regiones y generos, considerando, por supuesto, que para cada una de esas sub-poblaciones,
#las personas elegidas sean las de mejores promedios académicos.

import pandas as pd
import math
import matplotlib.pyplot as plt

lista_nombres_archivos = ['edad.txt','genero.txt','estado_civil.txt','escolaridad.txt','estrato.txt','region.txt','promedio.txt']

def automatizar_lectura(nombres_archivos):
    
    with open(nombres_archivos[0]) as f:
        text_list = f.readlines()
    
    cantidad_datos = len(text_list)
    indice = []
    ID_persona = []

    for i in range(cantidad_datos):
      indice.append(i)
      ID_persona.append(i+1)
        
    columnas = []
    for i in range(len(nombres_archivos)):
      nombre_columna = nombres_archivos[i].replace(".txt","")
      columnas.append(nombre_columna)

    columnas.insert(0, "ID")
    columnas.append("Beca asignada")
    no_columnas = len(columnas)
    
    df = pd.DataFrame(index = indice, columns = columnas)

    for j in range(cantidad_datos):
      df.iloc[j,0] = ID_persona[j]
      df.iloc[j,no_columnas-1] = "NO"

    for i in range(len(nombres_archivos)):
        with open(nombres_archivos[i]) as f:
            text_list = f.readlines()
        
        for j in range(len(text_list)):
            dato = text_list[j]
            dato = dato.replace("\n","")
            df.iloc[j,i+1] = dato

    return df

df_datos = automatizar_lectura(lista_nombres_archivos)

df_datos = df_datos.sort_values('promedio',ascending=False)
print(df_datos)
becas_a_entregar = int(input("Por favor ingrese el número de becas a entregar: "))
print("")

becas_entregadas = 0
becas_disponibles = becas_a_entregar - becas_entregadas
becas_agotadas = False
i=0

while (becas_agotadas == False):

  if i == len(df_datos):
    i = 0

  if (df_datos.iloc[i,8] == 'NO') and (becas_disponibles>0):

    #REGIÓN AMAZONIA
    if (df_datos.iloc[i,6] == 'Amazonia') and (df_datos.iloc[i,2] == 'masculino'):
      df_datos.iloc[i,8] = 'SI'
      becas_entregadas = becas_entregadas + 1
      becas_disponibles = becas_a_entregar - becas_entregadas
      if becas_disponibles == 0:
        becas_agotadas = True
    elif (df_datos.iloc[i,6] == 'Amazonia') and (df_datos.iloc[i,2] == 'femenino'):
      df_datos.iloc[i,8] = 'SI'
      becas_entregadas = becas_entregadas + 1
      becas_disponibles = becas_a_entregar - becas_entregadas
      if becas_disponibles == 0:
        becas_agotadas = True
    elif (df_datos.iloc[i,6] == 'Amazonia'):
      df_datos.iloc[i,8] = 'SI'
      becas_entregadas = becas_entregadas + 1
      becas_disponibles = becas_a_entregar - becas_entregadas
      if becas_disponibles == 0:
        becas_agotadas = True

    #REGIÓN ANDINA
    if (df_datos.iloc[i,6] == 'Andina') and (df_datos.iloc[i,2] == 'masculino'):
      df_datos.iloc[i,8] = 'SI'
      becas_entregadas = becas_entregadas + 1
      becas_disponibles = becas_a_entregar - becas_entregadas
      if becas_disponibles == 0:
        becas_agotadas = True
    elif (df_datos.iloc[i,6] == 'Andina') and (df_datos.iloc[i,2] == 'femenino'):
      df_datos.iloc[i,8] = 'SI'
      becas_entregadas = becas_entregadas + 1
      becas_disponibles = becas_a_entregar - becas_entregadas
      if becas_disponibles == 0:
        becas_agotadas = True

    #OTRO GENERO
    elif (df_datos.iloc[i,6] == 'Andina'):
      df_datos.iloc[i,8] = 'SI'
      becas_entregadas = becas_entregadas + 1
      becas_disponibles = becas_a_entregar - becas_entregadas
      if becas_disponibles == 0:
        becas_agotadas = True    

    #REGIÓN CARIBE
    if (df_datos.iloc[i,6] == 'Caribe') and (df_datos.iloc[i,2] == 'masculino'):
      df_datos.iloc[i,8] = 'SI'
      becas_entregadas = becas_entregadas + 1
      becas_disponibles = becas_a_entregar - becas_entregadas
      if becas_disponibles == 0:
        becas_agotadas = True
    elif (df_datos.iloc[i,6] == 'Caribe') and (df_datos.iloc[i,2] == 'femenino'):
      df_datos.iloc[i,8] = 'SI'
      becas_entregadas = becas_entregadas + 1
      becas_disponibles = becas_a_entregar - becas_entregadas
      if becas_disponibles == 0:
        becas_agotadas = True
    elif (df_datos.iloc[i,6] == 'Caribe'):
      df_datos.iloc[i,8] = 'SI'
      becas_entregadas = becas_entregadas + 1
      becas_disponibles = becas_a_entregar - becas_entregadas
      if becas_disponibles == 0:
        becas_agotadas = True  

    #REGIÓN PACÍFICA
    if (df_datos.iloc[i,6] == 'Pacifica') and (df_datos.iloc[i,2] == 'masculino'):
      df_datos.iloc[i,8] = 'SI'
      becas_entregadas = becas_entregadas + 1
      becas_disponibles = becas_a_entregar - becas_entregadas
      if becas_disponibles == 0:
        becas_agotadas = True
    elif (df_datos.iloc[i,6] == 'Pacifica') and (df_datos.iloc[i,2] == 'femenino'):
      df_datos.iloc[i,8] = 'SI'
      becas_entregadas = becas_entregadas + 1
      becas_disponibles = becas_a_entregar - becas_entregadas
      if becas_disponibles == 0:
        becas_agotadas = True
    elif (df_datos.iloc[i,6] == 'Pacifica'):
      df_datos.iloc[i,8] = 'SI'
      becas_entregadas = becas_entregadas + 1
      becas_disponibles = becas_a_entregar - becas_entregadas
      if becas_disponibles == 0:
        becas_agotadas = True   

    #REGIÓN ORINOQUIA
    if (df_datos.iloc[i,6] == 'Orinoquia') and (df_datos.iloc[i,2] == 'masculino'):
      df_datos.iloc[i,8] = 'SI'
      becas_entregadas = becas_entregadas + 1
      becas_disponibles = becas_a_entregar - becas_entregadas
      if becas_disponibles == 0:
        becas_agotadas = True
    elif (df_datos.iloc[i,6] == 'Orinoquia') and (df_datos.iloc[i,2] == 'femenino'):
      df_datos.iloc[i,8] = 'SI'
      becas_entregadas = becas_entregadas + 1
      becas_disponibles = becas_a_entregar - becas_entregadas
      if becas_disponibles == 0:
        becas_agotadas = True
    elif (df_datos.iloc[i,6] == 'Orinoquia'):
      df_datos.iloc[i,8] = 'SI'
      becas_entregadas = becas_entregadas + 1
      becas_disponibles = becas_a_entregar - becas_entregadas
      if becas_disponibles == 0:
        becas_agotadas = True  

  i = i + 1

print(df_datos)
print("")

df_grupo_asignacion2 = df_datos

no_becas_final_Amazonia_masc = df_datos['ID'][(df_datos.region == "Amazonia") & (df_datos.genero == 'masculino') & (df_datos.iloc[:,8] == 'SI')].count()
no_becas_final_Amazonia_fem = df_datos['ID'][(df_datos.region == "Amazonia") & (df_datos.genero == 'femenino') & (df_datos.iloc[:,8] == 'SI')].count()
no_becas_final_Amazonia_otros = df_datos['ID'][(df_datos.region == "Amazonia") & (df_datos.genero != 'masculino') & (df_datos.genero != 'femenino') & (df_datos.iloc[:,8] == 'SI')].count()

no_becas_final_Andina_masc = df_datos['ID'][(df_datos.region == "Andina") & (df_datos.genero == 'masculino') & (df_datos.iloc[:,8] == 'SI')].count()
no_becas_final_Andina_fem = df_datos['ID'][(df_datos.region == "Andina") & (df_datos.genero == 'femenino') & (df_datos.iloc[:,8] == 'SI')].count()
no_becas_final_Andina_otros = df_datos['ID'][(df_datos.region == "Andina") & (df_datos.genero != 'masculino') & (df_datos.genero != 'femenino') & (df_datos.iloc[:,8] == 'SI')].count()

no_becas_final_Caribe_masc = df_datos['ID'][(df_datos.region == "Caribe") & (df_datos.genero == 'masculino') & (df_datos.iloc[:,8] == 'SI')].count()
no_becas_final_Caribe_fem = df_datos['ID'][(df_datos.region == "Caribe") & (df_datos.genero == 'femenino') & (df_datos.iloc[:,8] == 'SI')].count()
no_becas_final_Caribe_otros = df_datos['ID'][(df_datos.region == "Caribe") & (df_datos.genero != 'masculino') & (df_datos.genero != 'femenino') & (df_datos.iloc[:,8] == 'SI')].count()

no_becas_final_Pacifica_masc = df_datos['ID'][(df_datos.region == "Pacifica") & (df_datos.genero == 'masculino') & (df_datos.iloc[:,8] == 'SI')].count()
no_becas_final_Pacifica_fem = df_datos['ID'][(df_datos.region == "Pacifica") & (df_datos.genero == 'femenino') & (df_datos.iloc[:,8] == 'SI')].count()
no_becas_final_Pacifica_otros = df_datos['ID'][(df_datos.region == "Pacifica") & (df_datos.genero != 'masculino') & (df_datos.genero != 'femenino') & (df_datos.iloc[:,8] == 'SI')].count()

no_becas_final_Orinoquia_masc = df_datos['ID'][(df_datos.region == "Orinoquia") & (df_datos.genero == 'masculino') & (df_datos.iloc[:,8] == 'SI')].count()
no_becas_final_Orinoquia_fem = df_datos['ID'][(df_datos.region == "Orinoquia") & (df_datos.genero == 'femenino') & (df_datos.iloc[:,8] == 'SI')].count()
no_becas_final_Orinoquia_otros = df_datos['ID'][(df_datos.region == "Orinoquia") & (df_datos.genero != 'masculino') & (df_datos.genero != 'femenino') & (df_datos.iloc[:,8] == 'SI')].count()


print("No. becas total entregadas: "+str(becas_entregadas)+"\n")
print("No. becas entregadas en Amazonia - genero masculino: "+str(no_becas_final_Amazonia_masc))
print("No. becas entregadas en Amazonia - genero femenino: "+str(no_becas_final_Amazonia_fem))
print("No. becas entregadas en Amazonia - genero otro: "+str(no_becas_final_Amazonia_otros)+"\n")

print("No. becas entregadas en Andina - genero masculino: "+str(no_becas_final_Andina_masc))
print("No. becas entregadas en Andina - genero femenino: "+str(no_becas_final_Andina_fem))
print("No. becas entregadas en Andina - genero otro: "+str(no_becas_final_Andina_otros)+"\n")

print("No. becas entregadas en Caribe - genero masculino: "+str(no_becas_final_Caribe_masc))
print("No. becas entregadas en Caribe - genero femenino: "+str(no_becas_final_Caribe_fem))
print("No. becas entregadas en Caribe - genero otro: "+str(no_becas_final_Caribe_otros)+"\n")

print("No. becas entregadas en Pacifica - genero masculino: "+str(no_becas_final_Pacifica_masc))
print("No. becas entregadas en Pacifica - genero femenino: "+str(no_becas_final_Pacifica_fem))
print("No. becas entregadas en Pacifica - genero otro: "+str(no_becas_final_Pacifica_otros)+"\n")

print("No. becas entregadas en Orinoquia - genero masculino: "+str(no_becas_final_Orinoquia_masc))
print("No. becas entregadas en Orinoquia - genero femenino: "+str(no_becas_final_Orinoquia_fem))
print("No. becas entregadas en Orinoquia - genero otro: "+str(no_becas_final_Orinoquia_otros)+"\n")

etiquetas = ["Amazonia-Masculino","Amazonia-Femenino","Amazonia-Otro",
             "Andina-Masculino","Andina-Femenino","Andina-Otro",
             "Caribe-Masculino","Caribe-Femenino","Caribe-Otro",
             "Pacifica-Masculino","Pacifica-Femenino","Pacifica-Otro",
             "Orinoquia-Masculino","Orinoquia-Femenino","Orinoquia-Otro"]

frec_reg_gen = [no_becas_final_Amazonia_masc,no_becas_final_Amazonia_fem,no_becas_final_Amazonia_otros,
                no_becas_final_Andina_masc,no_becas_final_Andina_fem,no_becas_final_Andina_otros,
                no_becas_final_Caribe_masc,no_becas_final_Caribe_fem,no_becas_final_Caribe_otros,
                no_becas_final_Pacifica_masc,no_becas_final_Pacifica_fem,no_becas_final_Pacifica_otros,
                no_becas_final_Orinoquia_masc,no_becas_final_Orinoquia_fem,no_becas_final_Orinoquia_otros]

plt.pie(frec_reg_gen,labels = etiquetas,
        colors = ["Red","Green","Yellow","Blue","Purple",
                  "pink","cyan","gold","brown","magenta",
                  "Red","Green","Yellow","Blue","Purple",
                  "pink","cyan","gold","brown","magenta",
                  "Red","Green","Yellow","Blue","Purple"],
        shadow = True,
        startangle = 90,
        radius = 2)

plt.show()

# %% [markdown]
# **Misión 6**
#
# Desarrollar un algoritmo, a partir de lo anterior, cuyo resultado permita al comité comparar fácilmente las características de las dos poblaciones hipotéticas que recibirían becas.
#
# *Ayuda*: considera utilizar tus implementaciones de la *Misión 2* para facilitar esta misión.

# %%
# código
df_g1 = df_final_grupo_asignacion1

rango0_1 = 0
rango1_2 = 0
rango2_3 = 0
rango3_4 = 0
rango4_5 = 0

for i in range(len(df_g1)):
  if (0 <= float(df_g1.iloc[i,7]) ) and (float(df_g1.iloc[i,7]) < 1) and df_g1.iloc[i,8] == 'SI':
    rango0_1 = rango0_1 + 1
  elif (1 <= float(df_g1.iloc[i,7]) ) and (float(df_g1.iloc[i,7]) < 2) and df_g1.iloc[i,8] == 'SI':
    rango1_2 = rango1_2 + 1
  elif (2 <= float(df_g1.iloc[i,7]) ) and (float(df_g1.iloc[i,7]) < 3) and df_g1.iloc[i,8] == 'SI':
    rango2_3 = rango2_3 + 1
  elif (3 <= float(df_g1.iloc[i,7]) ) and (float(df_g1.iloc[i,7]) < 4) and df_g1.iloc[i,8] == 'SI':
    rango3_4 = rango3_4 + 1
  elif (4 <= float(df_g1.iloc[i,7]) ) and (float(df_g1.iloc[i,7]) <= 5) and df_g1.iloc[i,8] == 'SI':
    rango4_5= rango4_5 + 1

print("Grupo 1: \n")
print("Rango promedio: \n")
print("No. becas rango 0-1: "+str(rango0_1))
print("No. becas rango 1-2: "+str(rango1_2))
print("No. becas rango 2-3: "+str(rango2_3))
print("No. becas rango 3-4: "+str(rango3_4))
print("No. becas rango 4-5: "+str(rango4_5))
print("")

frecuencia_por_rango_promedio_g1 = [rango0_1,rango1_2,rango2_3,rango3_4,rango4_5]

estrato1_2 = 0
estrato2_3 = 0
estrato3_4 = 0
estrato4_5 = 0
estrato5_6 = 0

for i in range(len(df_g1)):
  if (1 <= int(df_g1.iloc[i,5]) ) and (int(df_g1.iloc[i,5]) < 2) and df_g1.iloc[i,8] == 'SI':
    estrato1_2 = estrato1_2 + 1
  elif (2 <= int(df_g1.iloc[i,5]) ) and (int(df_g1.iloc[i,5]) < 3) and df_g1.iloc[i,8] == 'SI':
    estrato2_3 = estrato2_3 + 1
  elif (3 <= int(df_g1.iloc[i,5]) ) and (int(df_g1.iloc[i,5]) < 4) and df_g1.iloc[i,8] == 'SI':
    estrato3_4 = estrato3_4 + 1
  elif (4 <= int(df_g1.iloc[i,5]) ) and (int(df_g1.iloc[i,5]) < 5) and df_g1.iloc[i,8] == 'SI':
    estrato4_5 = estrato4_5 + 1
  elif (5 <= int(df_g1.iloc[i,5]) ) and (int(df_g1.iloc[i,5]) <= 6) and df_g1.iloc[i,8] == 'SI':
    estrato5_6= estrato5_6 + 1
print("")
print("Estratos: ")

import seaborn as sns

print("No. becas estrato1_2: "+str(estrato1_2))
print("No. becas estrato2_3: "+str(estrato2_3))
print("No. becas estrato3_4: "+str(estrato3_4))
print("No. becas estrato4_5: "+str(estrato4_5))
print("No. becas estrato5_6: "+str(estrato5_6))
print("")
etiquetasg1 = ['estrato1_2','estrato2_3','estrato3_4','estrato4_5','estrato5_6']
frecuencia_por_estratog1 = [estrato1_2,estrato2_3,estrato3_4,estrato4_5,estrato5_6]
#plt = sns.barplot(x = etiquetas, y = frecuencia_por_estrato)
#plt.set(xlabel = "Estrato", ylabel = "Frecuencia")
print("")

r_amazonia = 0
r_andina = 0
r_caribe = 0
r_orinoquia = 0
r_pacifica = 0

for i in range(len(df_g1)):
  if (df_g1.iloc[i,6] == 'Amazonia')  and (df_g1.iloc[i,8] == 'SI'):
    r_amazonia = r_amazonia + 1
  elif (df_g1.iloc[i,6] == 'Andina' ) and (df_g1.iloc[i,8] == 'SI'):
    r_andina = r_andina + 1
  elif (df_g1.iloc[i,6] == 'Caribe' ) and (df_g1.iloc[i,8] == 'SI'):
    r_caribe = r_caribe + 1
  elif (df_g1.iloc[i,6] == 'Orinoquia' ) and (df_g1.iloc[i,8] == 'SI'):
    r_orinoquia = r_orinoquia + 1
  elif (df_g1.iloc[i,6] == 'Pacifica' ) and (df_g1.iloc[i,8] == 'SI'):
    r_pacifica = r_pacifica + 1
print("")
print("Regiones: ")
print("No. becas r_amazonia: "+str(r_amazonia))
print("No. becas r_andina: "+str(r_andina))
print("No. becas r_caribe: "+str(r_caribe))
print("No. becas r_orinoquia: "+str(r_orinoquia))
print("No. becas r_pacifica: "+str(r_pacifica))

frecuencia_por_regiong1 = [r_amazonia,r_andina,r_caribe,r_orinoquia,r_pacifica]
print("")

df_g2 = df_grupo_asignacion2

rango0_1 = 0
rango1_2 = 0
rango2_3 = 0
rango3_4 = 0
rango4_5 = 0

for i in range(len(df_g2)):
  if (0 <= float(df_g2.iloc[i,7]) ) and (float(df_g2.iloc[i,7]) < 1) and df_g2.iloc[i,8] == 'SI':
    rango0_1 = rango0_1 + 1
  elif (1 <= float(df_g2.iloc[i,7]) ) and (float(df_g2.iloc[i,7]) < 2) and df_g2.iloc[i,8] == 'SI':
    rango1_2 = rango1_2 + 1
  elif (2 <= float(df_g2.iloc[i,7]) ) and (float(df_g2.iloc[i,7]) < 3) and df_g2.iloc[i,8] == 'SI':
    rango2_3 = rango2_3 + 1
  elif (3 <= float(df_g2.iloc[i,7]) ) and (float(df_g2.iloc[i,7]) < 4) and df_g2.iloc[i,8] == 'SI':
    rango3_4 = rango3_4 + 1
  elif (4 <= float(df_g2.iloc[i,7]) ) and (float(df_g2.iloc[i,7]) <= 5) and df_g2.iloc[i,8] == 'SI':
    rango4_5= rango4_5 + 1
print("")
print("Grupo 2: ")
print("")
print("Rangos promedio: ")
print("No. becas rango 0-1: "+str(rango0_1))
print("No. becas rango 1-2: "+str(rango1_2))
print("No. becas rango 2-3: "+str(rango2_3))
print("No. becas rango 3-4: "+str(rango3_4))
print("No. becas rango 4-5: "+str(rango4_5))
frecuencia_por_rango_promedio_g2 = [rango0_1,rango1_2,rango2_3,rango3_4,rango4_5]

estrato1_2 = 0
estrato2_3 = 0
estrato3_4 = 0
estrato4_5 = 0
estrato5_6 = 0

for i in range(len(df_g2)):
  if (1 <= int(df_g2.iloc[i,5]) ) and (int(df_g2.iloc[i,5]) < 2) and df_g2.iloc[i,8] == 'SI':
    estrato1_2 = estrato1_2 + 1
  elif (2 <= int(df_g2.iloc[i,5]) ) and (int(df_g2.iloc[i,5]) < 3) and df_g2.iloc[i,8] == 'SI':
    estrato2_3 = estrato2_3 + 1
  elif (3 <= int(df_g2.iloc[i,5]) ) and (int(df_g2.iloc[i,5]) < 4) and df_g2.iloc[i,8] == 'SI':
    estrato3_4 = estrato3_4 + 1
  elif (4 <= int(df_g2.iloc[i,5]) ) and (int(df_g2.iloc[i,5]) < 5) and df_g2.iloc[i,8] == 'SI':
    estrato4_5 = estrato4_5 + 1
  elif (5 <= int(df_g2.iloc[i,5]) ) and (int(df_g2.iloc[i,5]) <= 6) and df_g2.iloc[i,8] == 'SI':
    estrato5_6= estrato5_6 + 1
print("")
print("Estratos: ")
print("No. becas estrato1_2: "+str(estrato1_2))
print("No. becas estrato2_3: "+str(estrato2_3))
print("No. becas estrato3_4: "+str(estrato3_4))
print("No. becas estrato4_5: "+str(estrato4_5))
print("No. becas estrato5_6: "+str(estrato5_6))

etiquetasg2 = ['estrato1_2','estrato2_3','estrato3_4','estrato4_5','estrato5_6']
frecuencia_por_estratog2 = [estrato1_2,estrato2_3,estrato3_4,estrato4_5,estrato5_6]

r_amazonia = 0
r_andina = 0
r_caribe = 0
r_orinoquia = 0
r_pacifica = 0

for i in range(len(df_g2)):
  if (df_g2.iloc[i,6] == 'Amazonia')  and (df_g2.iloc[i,8] == 'SI'):
    r_amazonia = r_amazonia + 1
  elif (df_g2.iloc[i,6] == 'Andina' ) and (df_g2.iloc[i,8] == 'SI'):
    r_andina = r_andina + 1
  elif (df_g2.iloc[i,6] == 'Caribe' ) and (df_g2.iloc[i,8] == 'SI'):
    r_caribe = r_caribe + 1
  elif (df_g2.iloc[i,6] == 'Orinoquia' ) and (df_g2.iloc[i,8] == 'SI'):
    r_orinoquia = r_orinoquia + 1
  elif (df_g2.iloc[i,6] == 'Pacifica' ) and (df_g2.iloc[i,8] == 'SI'):
    r_pacifica = r_pacifica + 1
print("")
print("Regiones: ")
print("No. becas r_amazonia: "+str(r_amazonia))
print("No. becas r_andina: "+str(r_andina))
print("No. becas r_caribe: "+str(r_caribe))
print("No. becas r_orinoquia: "+str(r_orinoquia))
print("No. becas r_pacifica: "+str(r_pacifica))

frecuencia_por_regiong2 = [r_amazonia,r_andina,r_caribe,r_orinoquia,r_pacifica]
print("")

import matplotlib.pyplot as plt
import numpy as np

print("Gráfico estrato g1-g2: ")
print("")
etiquetasg2 = ['estrato1_2','estrato2_3','estrato3_4','estrato4_5','estrato5_6']
#frecuencia_por_estratog1
#frecuencia_por_estratog2
numero_de_grupos = len(frecuencia_por_estratog1)
indice_barras = np.arange(numero_de_grupos)
ancho_barras = 0.35
plt.bar(indice_barras, frecuencia_por_estratog1, width=ancho_barras, label="Estrato g1")
plt.bar(indice_barras + ancho_barras, frecuencia_por_estratog2, width=ancho_barras, label="Estrato g2")
plt.legend(loc = 'best')
plt.xticks(indice_barras+ancho_barras,etiquetasg2)
plt.ylabel('Frecuencia')
plt.xlabel('Estrato')
plt.title('Frecuencia por estrato')
plt.show()
print("")

print("Gráfico promedio g1-g2: ")
print("")
etiquetas_rango = ['rango 0-1','rango 1-2','rango 2-3','rango 3-4','rango 4-5']
#frecuencia_por_rango_promedio_g1
#frecuencia_por_rango_promedio_g2
numero_de_grupos = len(frecuencia_por_rango_promedio_g1)
indice_barras = np.arange(numero_de_grupos)
ancho_barras = 0.35
plt.bar(indice_barras, frecuencia_por_rango_promedio_g1, width=ancho_barras, label="Rangos promedio g1")
plt.bar(indice_barras + ancho_barras, frecuencia_por_rango_promedio_g2, width=ancho_barras, label="Rangos promedio g2")
plt.legend(loc = 'best')
plt.xticks(indice_barras+ancho_barras,etiquetas_rango)
plt.ylabel('Frecuencia')
plt.xlabel('Rangos promedio')
plt.title('Frecuencia por rangos de promedio')
plt.show()
print("")

print("Gráfico región g1-g2: ")
print("")
etiquetas_regiones = ['Amazonía','Andina','Caribe','Orinoquia','Pacífico']
#frecuencia_por_regiong1
#frecuencia_por_regiong2
numero_de_grupos = len(frecuencia_por_regiong1)
indice_barras = np.arange(numero_de_grupos)
ancho_barras = 0.35
plt.bar(indice_barras, frecuencia_por_regiong1, width=ancho_barras, label="regiones g1")
plt.bar(indice_barras + ancho_barras, frecuencia_por_regiong2, width=ancho_barras, label="regiones g2")
plt.legend(loc = 'best')
plt.xticks(indice_barras+ancho_barras,etiquetas_regiones)
plt.ylabel('Frecuencia')
plt.xlabel('Regiones')
plt.title('Frecuencia por regiones')
plt.show()

# %% [markdown]
# ## 3. Desarrollo de una solución analítica
#
# Reconociendo la complejidad de este problema (que no permite reducirlo a una dicotomía) y viendo el potencial del análisis de datos para enriquecer la discusión y los insumos para tomar decisiones, el comité ha solicitado una herramienta analítica que les permita . Sus requerimientos son:
#
# * La herramienta debe permitir ingresar una política de selección de becados.
#     * Se debe poder elegir el rango de edad de los aspirantes.
#     * Se debe poder elegir qué proporción de las becas se asigna a cada género, a cada estrato, o a cada región (pero sólo debe elegirse uno de estos criterios).
# * La herramienta debe generar un resultado que permita al comité analizar las características de la población potencialmente elegida si se usara la política ingresada.
#
# **Misión 7**
#
# Desarrollar, a partir de lo construido hasta el momento, un algoritmo que permita cumplir con los requerimientos del comité.

# %%
# código
import pandas as pd
import math
import matplotlib.pyplot as plt

lista_nombres_archivos = ['edad.txt','genero.txt','estado_civil.txt','escolaridad.txt','estrato.txt','region.txt','promedio.txt']

def automatizar_lectura(nombres_archivos):
    
    with open(nombres_archivos[0]) as f:
        text_list = f.readlines()
    
    cantidad_datos = len(text_list)
    indice = []
    ID_persona = []

    for i in range(cantidad_datos):
      indice.append(i)
      ID_persona.append(i+1)
        
    columnas = []
    for i in range(len(nombres_archivos)):
      nombre_columna = nombres_archivos[i].replace(".txt","")
      columnas.append(nombre_columna)

    columnas.insert(0, "ID")
    columnas.append("Beca asignada")
    no_columnas = len(columnas)
    
    df = pd.DataFrame(index = indice, columns = columnas)
    

    for j in range(cantidad_datos):
      df.iloc[j,0] = ID_persona[j]
      df.iloc[j,no_columnas-1] = "NO"
    

    for i in range(len(nombres_archivos)):
        with open(nombres_archivos[i]) as f:
            text_list = f.readlines()
        
        for j in range(len(text_list)):
            dato = text_list[j]
            dato = dato.replace("\n","")
            df.iloc[j,i+1] = dato

    return df

df_datos = automatizar_lectura(lista_nombres_archivos)
#print(df_datos)

#Se debe poder elegir el rango de edad de los aspirantes.
#Se debe poder elegir qué proporción de las becas se asigna a cada género, a cada estrato,
#o a cada región (pero sólo debe elegirse uno de estos criterios).

numero1_rango_edad = int(input("Por favor ingrese el límite inferior del rango de edad de los aspirantes a recibir beca: "))
numero2_rango_edad = int(input("Por favor ingrese el límite superior del rango de edad de los aspirantes a recibir beca: "))
print("")
pob_entre_rango_edad = 0
for i in range(len(df_datos)):
  if (numero1_rango_edad <= int(df_datos.iloc[i,1])) and (int(df_datos.iloc[i,1]) <= numero2_rango_edad):
    pob_entre_rango_edad = pob_entre_rango_edad + 1
print("Población entre rango de edad: "+str(pob_entre_rango_edad))

cantidad_becas_a_entregar = int(input("Por favor ingrese la cantidad de becas a entregar entre (0 - "+str(pob_entre_rango_edad)+"): "))
print("")

parametro_eleccion = input("Por favor ingrese el criterio de elección para repartir las becas, de la siguiente manera (genero,estrato,region): ")
if parametro_eleccion == 'genero':
  print("\nA continuación seleccionará la proporción para géreno masculino, femenino y otro genero\n")
  proporcion_becas_gmasculino = float(input("Por favor ingrese la proporción de becas (0-1) que se destinarán a género masculino: "))
  print("Proporción género masculino: "+str(proporcion_becas_gmasculino))
  p_gf = 1-proporcion_becas_gmasculino
  proporcion_becas_gfemenino = float(input("Por favor ingrese la proporción de becas (0 - "+str(p_gf)+") que se destinarán a género femenino: "))
  print("Proporción género femenino: "+str(proporcion_becas_gfemenino))
  proporcion_becas_otro_genero = 1-proporcion_becas_gmasculino-proporcion_becas_gfemenino
  print("Proporción otro género: "+str(round(proporcion_becas_otro_genero,2)))

  becas_agotadas = False  

  becas_entregadas_gmasculino = 0
  becas_entregadas_gfemenino = 0
  becas_entregadas_otro_genero = 0

  import math
  print("")
  no_becas_entregar_gmasculino = cantidad_becas_a_entregar*proporcion_becas_gmasculino
  no_becas_entregar_gmasculino = math.ceil(no_becas_entregar_gmasculino)
  print("Número becas a entregar género masculino: "+str(no_becas_entregar_gmasculino))

  no_becas_entregar_gfemenino = cantidad_becas_a_entregar*proporcion_becas_gfemenino
  no_becas_entregar_gfemenino = math.ceil(no_becas_entregar_gfemenino)
  print("Número becas a entregar género femenino: "+str(no_becas_entregar_gfemenino))

  no_becas_entregar_otro_genero = cantidad_becas_a_entregar*proporcion_becas_otro_genero
  no_becas_entregar_otro_genero = math.ceil(no_becas_entregar_otro_genero)
  print("Número becas a entregar otro género: "+str(no_becas_entregar_otro_genero))
  print("")

  becas_disponibles_gmasculino = no_becas_entregar_gmasculino - becas_entregadas_gmasculino
  becas_disponibles_gfemenino = no_becas_entregar_gfemenino - becas_entregadas_gfemenino
  becas_disponibles_otro_genero = no_becas_entregar_otro_genero - becas_entregadas_otro_genero
  iterador = 0

  while becas_agotadas == False:

    if (df_datos.iloc[iterador,2] == 'masculino') and (becas_disponibles_gmasculino > 0) and (df_datos.iloc[iterador,8] == 'NO') and (numero1_rango_edad <= int(df_datos.iloc[iterador,1])) and (int(df_datos.iloc[iterador,1]) <= numero2_rango_edad):
      df_datos.iloc[iterador,8] = 'SI'
      becas_entregadas_gmasculino = becas_entregadas_gmasculino + 1
      becas_disponibles_gmasculino = no_becas_entregar_gmasculino - becas_entregadas_gmasculino
      
      if (becas_disponibles_gmasculino == 0) and (becas_disponibles_gfemenino == 0) and (becas_disponibles_otro_genero == 0):
        becas_agotadas = True
      
    if iterador < (len(df_datos)-1):
      iterador = iterador + 1
    else:
      iterador = 0

    if (df_datos.iloc[iterador,2] == 'femenino') and (becas_disponibles_gfemenino > 0) and (df_datos.iloc[iterador,8] == 'NO') and (numero1_rango_edad <= int(df_datos.iloc[iterador,1])) and (int(df_datos.iloc[iterador,1]) <= numero2_rango_edad):
      df_datos.iloc[iterador,8] = 'SI'
      becas_entregadas_gfemenino = becas_entregadas_gfemenino + 1
      becas_disponibles_gfemenino = no_becas_entregar_gfemenino - becas_entregadas_gfemenino
    if iterador < (len(df_datos)-1):
      iterador = iterador + 1
    else:
      iterador = 0
      
      if (becas_disponibles_gmasculino == 0) and (becas_disponibles_gfemenino == 0) and (becas_disponibles_otro_genero == 0):
        becas_agotadas = True

    if (df_datos.iloc[iterador,2] != 'femenino') and (df_datos.iloc[iterador,2] != 'masculino') and (becas_disponibles_otro_genero > 0) and (df_datos.iloc[iterador,8] == 'NO') and (numero1_rango_edad <= int(df_datos.iloc[iterador,1])) and (int(df_datos.iloc[iterador,1]) <= numero2_rango_edad):
      df_datos.iloc[iterador,8] = 'SI'
      becas_entregadas_otro_genero = becas_entregadas_otro_genero + 1
      becas_disponibles_otro_genero = no_becas_entregar_otro_genero - becas_entregadas_otro_genero
    if iterador < (len(df_datos)-1):
      iterador = iterador + 1
    else:
      iterador = 0
      
      if (becas_disponibles_gmasculino == 0) and (becas_disponibles_gfemenino == 0) and (becas_disponibles_otro_genero == 0):
        becas_agotadas = True

  pob_gen_masc_con_beca = 0
  for i in range(len(df_datos)):
    if (df_datos.iloc[i,2] == 'masculino') and (df_datos.iloc[i,8] == 'SI'):
      pob_gen_masc_con_beca = pob_gen_masc_con_beca + 1

  pob_gen_fem_con_beca = 0
  for i in range(len(df_datos)):
    if (df_datos.iloc[i,2] == 'femenino') and (df_datos.iloc[i,8] == 'SI'):
      pob_gen_fem_con_beca = pob_gen_fem_con_beca + 1

  pob_otro_gen_con_beca = 0
  for i in range(len(df_datos)):
    if (df_datos.iloc[i,2] != 'femenino') and (df_datos.iloc[i,2] != 'masculino') and (df_datos.iloc[i,8] == 'SI'):
      pob_otro_gen_con_beca = pob_otro_gen_con_beca + 1

  print("")
  print("Población género masculino con beca: "+str(pob_gen_masc_con_beca))
  print("Población género femenino con beca: "+str(pob_gen_fem_con_beca))
  print("Población otro género con beca: "+str(pob_otro_gen_con_beca))
  print("")


print(df_datos)

#Código para estrato:

#proporcion_estrato1 = float(input("Por favor ingrese la proporción en decimales para asignar al estrato 1 (0-1): "))
#proporcion_estrato2 = float(input("Por favor ingrese la proporción en decimales para asignar al estrato 2 (0-1): "))
#proporcion_estrato3 = float(input("Por favor ingrese la proporción en decimales para asignar al estrato 3 (0-1): "))
#proporcion_estrato4 = float(input("Por favor ingrese la proporción en decimales para asignar al estrato 4 (0-1): "))
#proporcion_estrato5 = float(input("Por favor ingrese la proporción en decimales para asignar al estrato 5 (0-1): "))
#print("")

# %% [markdown]
# **Misión 8**
#
# Proponer, con base en tu propio uso de la herramienta, una política de ingreso que consideres apropiada dado el contexto proporcionado. Si lo crees adecuado, explica, máximo 500 caracteres, las virtudes de tu propuesta (esto puede estar soportado en los datos, o no).

# %%
# respuesta en texto (solo leeremos los primeros 300 caracteres de la respuesta)

#mejor promedio;rango edad: menor 30 años; genero: mujer; region
#(pacifico 30%, caribe 30%, orinoquia 15%  amazonia 15% y andina 10%

respuesta = ''

import pandas as pd
import math
import matplotlib.pyplot as plt

lista_nombres_archivos = ['edad.txt','genero.txt','estado_civil.txt','escolaridad.txt','estrato.txt','region.txt','promedio.txt']

def automatizar_lectura(nombres_archivos):
    
    with open(nombres_archivos[0]) as f:
        text_list = f.readlines()
    
    cantidad_datos = len(text_list)
    indice = []
    ID_persona = []

    for i in range(cantidad_datos):
      indice.append(i)
      ID_persona.append(i+1)
        
    columnas = []
    for i in range(len(nombres_archivos)):
      nombre_columna = nombres_archivos[i].replace(".txt","")
      columnas.append(nombre_columna)

    columnas.insert(0, "ID")
    columnas.append("Beca asignada")
    no_columnas = len(columnas)
    
    df = pd.DataFrame(index = indice, columns = columnas)
    

    for j in range(cantidad_datos):
      df.iloc[j,0] = ID_persona[j]
      df.iloc[j,no_columnas-1] = "NO"
    

    for i in range(len(nombres_archivos)):
        with open(nombres_archivos[i]) as f:
            text_list = f.readlines()
        
        for j in range(len(text_list)):
            dato = text_list[j]
            dato = dato.replace("\n","")
            df.iloc[j,i+1] = dato

    return df

df_datos = automatizar_lectura(lista_nombres_archivos)
df_datos = df_datos.sort_values('promedio',ascending=False)
#print(df_datos)

#Se debe poder elegir el rango de edad de los aspirantes.
#Se debe poder elegir qué proporción de las becas se asigna a cada género, a cada estrato,
#o a cada región (pero sólo debe elegirse uno de estos criterios).

def Ejecutar_programa_por_genero():
    
    numero1_rango_edad = int(input("Por favor ingrese el límite inferior del rango de edad de los aspirantes a recibir beca (Programa por género): "))
    numero2_rango_edad = int(input("Por favor ingrese el límite superior del rango de edad de los aspirantes a recibir beca (Programa por género): "))
    print("")
    no_pob_gmasculino_entre_rangoedad = 0
    for i in range(len(df_datos)):
        if (df_datos.iloc[i,2] == 'masculino') and (numero1_rango_edad <= int(df_datos.iloc[i,1])) and (int(df_datos.iloc[i,1]) <= numero2_rango_edad):
            no_pob_gmasculino_entre_rangoedad = no_pob_gmasculino_entre_rangoedad + 1
            
    no_pob_gfemenino_entre_rangoedad = 0
    for i in range(len(df_datos)):
        if (df_datos.iloc[i,2] == 'femenino') and (numero1_rango_edad <= int(df_datos.iloc[i,1])) and (int(df_datos.iloc[i,1]) <= numero2_rango_edad):
            no_pob_gfemenino_entre_rangoedad = no_pob_gfemenino_entre_rangoedad + 1
            
    no_pob_otro_genero_entre_rangoedad = 0
    for i in range(len(df_datos)):
        if (df_datos.iloc[i,2] != 'femenino') and (df_datos.iloc[i,2] != 'masculino') and (numero1_rango_edad <= int(df_datos.iloc[i,1])) and (int(df_datos.iloc[i,1]) <= numero2_rango_edad):
            no_pob_otro_genero_entre_rangoedad = no_pob_otro_genero_entre_rangoedad + 1
    
    print("Cantidad de población género masculino entre rango de edad ("+str(numero1_rango_edad)+" - "+str(numero2_rango_edad)+"): "+str(no_pob_gmasculino_entre_rangoedad))
    print("Cantidad de población género femenino entre rango de edad ("+str(numero1_rango_edad)+" - "+str(numero2_rango_edad)+"): "+str(no_pob_gfemenino_entre_rangoedad))
    print("Cantidad de población otro género entre rango de edad ("+str(numero1_rango_edad)+" - "+str(numero2_rango_edad)+"): "+str(no_pob_otro_genero_entre_rangoedad))
    print("")
    cantidad_becas_a_entregar_gmasculino = int(input("Por favor ingrese la cantidad de becas a entregar para género masculino entre 0 y "+str(no_pob_gmasculino_entre_rangoedad)+": "))
    cantidad_becas_a_entregar_gfemenino = int(input("Por favor ingrese la cantidad de becas a entregar para género femenino entre 0 y "+str(no_pob_gfemenino_entre_rangoedad)+": "))
    cantidad_becas_a_entregar_otro_genero = int(input("Por favor ingrese la cantidad de becas a entregar para otro género entre 0 y "+str(no_pob_otro_genero_entre_rangoedad)+": "))
    print("")
    print("Becas a entregar para género masculino: "+str(cantidad_becas_a_entregar_gmasculino))
    print("Becas a entregar para género femenino: "+str(cantidad_becas_a_entregar_gfemenino))
    print("Becas a entregar para otro género: "+str(cantidad_becas_a_entregar_otro_genero))
    print("")
    print("No. total becas a entregar: "+str(cantidad_becas_a_entregar_gmasculino + cantidad_becas_a_entregar_gfemenino + cantidad_becas_a_entregar_otro_genero))
    print("")
    
    becas_agotadas = False  

    becas_entregadas_gmasculino = 0
    becas_entregadas_gfemenino = 0
    becas_entregadas_otro_genero = 0
    
    no_becas_entregar_gmasculino = cantidad_becas_a_entregar_gmasculino
    no_becas_entregar_gfemenino = cantidad_becas_a_entregar_gfemenino
    no_becas_entregar_otro_genero = cantidad_becas_a_entregar_otro_genero
    
    becas_disponibles_gmasculino = no_becas_entregar_gmasculino - becas_entregadas_gmasculino
    becas_disponibles_gfemenino = no_becas_entregar_gfemenino- becas_entregadas_gfemenino
    becas_disponibles_otro_genero = no_becas_entregar_otro_genero - becas_entregadas_otro_genero
    
    iterador = 0
    
    while becas_agotadas == False:

        #Género masculino
        if (df_datos.iloc[iterador,2] == 'masculino') and (becas_disponibles_gmasculino > 0) and (df_datos.iloc[iterador,8] == 'NO') and (numero1_rango_edad <= int(df_datos.iloc[iterador,1])) and (int(df_datos.iloc[iterador,1]) <= numero2_rango_edad):
            df_datos.iloc[iterador,8] = 'SI'
            becas_entregadas_gmasculino = becas_entregadas_gmasculino + 1
            becas_disponibles_gmasculino = no_becas_entregar_gmasculino - becas_entregadas_gmasculino
            if (becas_disponibles_gmasculino == 0) and (becas_disponibles_gfemenino == 0) and (becas_disponibles_otro_genero == 0):
                becas_agotadas = True
            
        if (becas_disponibles_gmasculino == 0) and (becas_disponibles_gfemenino == 0) and (becas_disponibles_otro_genero == 0):
            becas_agotadas = True
    
        if iterador < (len(df_datos)-1):
            iterador = iterador + 1
        else:
            iterador = 0
          
        #Género femenino
        if (df_datos.iloc[iterador,2] == 'femenino') and (becas_disponibles_gfemenino > 0) and (df_datos.iloc[iterador,8] == 'NO') and (numero1_rango_edad <= int(df_datos.iloc[iterador,1])) and (int(df_datos.iloc[iterador,1]) <= numero2_rango_edad):
            df_datos.iloc[iterador,8] = 'SI'
            becas_entregadas_gfemenino = becas_entregadas_gfemenino + 1
            becas_disponibles_gfemenino = no_becas_entregar_gfemenino - becas_entregadas_gfemenino
            if (becas_disponibles_gmasculino == 0) and (becas_disponibles_gfemenino == 0) and (becas_disponibles_otro_genero == 0):
                becas_agotadas = True
            
        if (becas_disponibles_gmasculino == 0) and (becas_disponibles_gfemenino == 0) and (becas_disponibles_otro_genero == 0):
            becas_agotadas = True
    
        if iterador < (len(df_datos)-1):
            iterador = iterador + 1
        else:
            iterador = 0
          
        #Otro género
        if (df_datos.iloc[iterador,2] != 'masculino') and (df_datos.iloc[iterador,2] != 'femenino') and (becas_disponibles_otro_genero > 0) and (df_datos.iloc[iterador,8] == 'NO') and (numero1_rango_edad <= int(df_datos.iloc[iterador,1])) and (int(df_datos.iloc[iterador,1]) <= numero2_rango_edad):
            df_datos.iloc[iterador,8] = 'SI'
            becas_entregadas_otro_genero = becas_entregadas_otro_genero + 1
            becas_disponibles_otro_genero = no_becas_entregar_otro_genero - becas_entregadas_otro_genero
            if (becas_disponibles_gmasculino == 0) and (becas_disponibles_gfemenino == 0) and (becas_disponibles_otro_genero == 0):
                becas_agotadas = True
            
        if (becas_disponibles_gmasculino == 0) and (becas_disponibles_gfemenino == 0) and (becas_disponibles_otro_genero == 0):
            becas_agotadas = True
    
        if iterador < (len(df_datos)-1):
            iterador = iterador + 1
        else:
            iterador = 0
          
    print("")
    print("Becas total entregadas: "+str(becas_entregadas_gmasculino + becas_entregadas_gfemenino + becas_entregadas_otro_genero))
    print("")
    print("Becas entregadas género masculino: "+str(becas_entregadas_gmasculino))
    print("Becas entregadas género femenino: "+str(becas_entregadas_gfemenino))
    print("Becas entregadas otro género: "+str(becas_entregadas_otro_genero))
    print("")
    frecuencia_por_genero = [becas_entregadas_gmasculino,becas_entregadas_gfemenino,becas_entregadas_otro_genero]

    poblacion_estrato1_con_beca_pg = df_datos['Beca asignada'][(df_datos['Beca asignada'] == 'SI') & (df_datos['estrato'] == '1')].count()
    poblacion_estrato2_con_beca_pg = df_datos['Beca asignada'][(df_datos['Beca asignada'] == 'SI') & (df_datos['estrato'] == '2')].count()
    poblacion_estrato3_con_beca_pg = df_datos['Beca asignada'][(df_datos['Beca asignada'] == 'SI') & (df_datos['estrato'] == '3')].count()
    poblacion_estrato4_con_beca_pg = df_datos['Beca asignada'][(df_datos['Beca asignada'] == 'SI') & (df_datos['estrato'] == '4')].count()
    poblacion_estrato5_con_beca_pg = df_datos['Beca asignada'][(df_datos['Beca asignada'] == 'SI') & (df_datos['estrato'] == '5')].count()
    frecuencia_por_edad = [poblacion_estrato1_con_beca_pg,poblacion_estrato2_con_beca_pg,poblacion_estrato3_con_beca_pg,poblacion_estrato4_con_beca_pg,poblacion_estrato5_con_beca_pg]

    poblacion_ramazonia_con_beca_pg = df_datos['Beca asignada'][(df_datos['Beca asignada'] == 'SI') & (df_datos['region'] == 'Amazonia')].count()
    poblacion_randina_con_beca_pg = df_datos['Beca asignada'][(df_datos['Beca asignada'] == 'SI') & (df_datos['region'] == 'Andina')].count()
    poblacion_rcaribe_con_beca_pg = df_datos['Beca asignada'][(df_datos['Beca asignada'] == 'SI') & (df_datos['region'] == 'Caribe')].count()
    poblacion_rorinoquia_con_beca_pg = df_datos['Beca asignada'][(df_datos['Beca asignada'] == 'SI') & (df_datos['region'] == 'Orinoquia')].count()
    poblacion_rpacifico_con_beca_pg = df_datos['Beca asignada'][(df_datos['Beca asignada'] == 'SI') & (df_datos['region'] == 'Pacifica')].count()
    frecuencia_por_region_pg = [poblacion_ramazonia_con_beca_pg, poblacion_randina_con_beca_pg, poblacion_rcaribe_con_beca_pg, poblacion_rorinoquia_con_beca_pg, poblacion_rpacifico_con_beca_pg]

    return frecuencia_por_genero,frecuencia_por_edad,frecuencia_por_region_pg

datos_programa_por_genero = Ejecutar_programa_por_genero()

import pandas as pd
import math
import matplotlib.pyplot as plt

lista_nombres_archivos = ['edad.txt','genero.txt','estado_civil.txt','escolaridad.txt','estrato.txt','region.txt','promedio.txt']

def automatizar_lectura(nombres_archivos):
    
    with open(nombres_archivos[0]) as f:
        text_list = f.readlines()
    
    cantidad_datos = len(text_list)
    indice = []
    ID_persona = []

    for i in range(cantidad_datos):
      indice.append(i)
      ID_persona.append(i+1)
        
    columnas = []
    for i in range(len(nombres_archivos)):
      nombre_columna = nombres_archivos[i].replace(".txt","")
      columnas.append(nombre_columna)

    columnas.insert(0, "ID")
    columnas.append("Beca asignada")
    no_columnas = len(columnas)
    
    df = pd.DataFrame(index = indice, columns = columnas)
    

    for j in range(cantidad_datos):
      df.iloc[j,0] = ID_persona[j]
      df.iloc[j,no_columnas-1] = "NO"
    

    for i in range(len(nombres_archivos)):
        with open(nombres_archivos[i]) as f:
            text_list = f.readlines()
        
        for j in range(len(text_list)):
            dato = text_list[j]
            dato = dato.replace("\n","")
            df.iloc[j,i+1] = dato

    return df

df_datos = automatizar_lectura(lista_nombres_archivos)
df_datos = df_datos.sort_values('promedio',ascending=False)
#print(df_datos)

#Se debe poder elegir el rango de edad de los aspirantes.
#Se debe poder elegir qué proporción de las becas se asigna a cada género, a cada estrato,
#o a cada región (pero sólo debe elegirse uno de estos criterios).

def Ejecutar_programa_por_region():
    
    numero1_rango_edad = int(input("Por favor ingrese el límite inferior del rango de edad de los aspirantes a recibir beca (Programa por región): "))
    numero2_rango_edad = int(input("Por favor ingrese el límite superior del rango de edad de los aspirantes a recibir beca (Programa por región): "))
    print("")
    no_pob_reg_amazonia_entre_rangoedad = 0
    for i in range(len(df_datos)):
        if (df_datos.iloc[i,6] == 'Amazonia') and (numero1_rango_edad <= int(df_datos.iloc[i,1])) and (int(df_datos.iloc[i,1]) <= numero2_rango_edad):
            no_pob_reg_amazonia_entre_rangoedad = no_pob_reg_amazonia_entre_rangoedad + 1
    
    no_pob_reg_andina_entre_rangoedad = 0
    for i in range(len(df_datos)):
        if (df_datos.iloc[i,6] == 'Andina') and (numero1_rango_edad <= int(df_datos.iloc[i,1])) and (int(df_datos.iloc[i,1]) <= numero2_rango_edad):
            no_pob_reg_andina_entre_rangoedad = no_pob_reg_andina_entre_rangoedad + 1
    
    no_pob_reg_caribe_entre_rangoedad = 0
    for i in range(len(df_datos)):
        if (df_datos.iloc[i,6] == 'Caribe') and (numero1_rango_edad <= int(df_datos.iloc[i,1])) and (int(df_datos.iloc[i,1]) <= numero2_rango_edad):
            no_pob_reg_caribe_entre_rangoedad = no_pob_reg_caribe_entre_rangoedad + 1
        
    no_pob_reg_orinoquia_entre_rangoedad = 0
    for i in range(len(df_datos)):
        if (df_datos.iloc[i,6] == 'Orinoquia') and (numero1_rango_edad <= int(df_datos.iloc[i,1])) and (int(df_datos.iloc[i,1]) <= numero2_rango_edad):
            no_pob_reg_orinoquia_entre_rangoedad = no_pob_reg_orinoquia_entre_rangoedad + 1
    
    no_pob_reg_pacifico_entre_rangoedad = 0
    for i in range(len(df_datos)):
        if (df_datos.iloc[i,6] == 'Pacifica') and (numero1_rango_edad <= int(df_datos.iloc[i,1])) and (int(df_datos.iloc[i,1]) <= numero2_rango_edad):
            no_pob_reg_pacifico_entre_rangoedad = no_pob_reg_pacifico_entre_rangoedad + 1
            
    print("Cantidad de población en región amazonía entre rango de edad ("+str(numero1_rango_edad)+" - "+str(numero2_rango_edad)+"): "+str(no_pob_reg_amazonia_entre_rangoedad))
    print("Cantidad de población en región andina entre rango de edad ("+str(numero1_rango_edad)+" - "+str(numero2_rango_edad)+"): "+str(no_pob_reg_andina_entre_rangoedad))
    print("Cantidad de población en región caribe entre rango de edad ("+str(numero1_rango_edad)+" - "+str(numero2_rango_edad)+"): "+str(no_pob_reg_caribe_entre_rangoedad))
    print("Cantidad de población en región orinoquía entre rango de edad ("+str(numero1_rango_edad)+" - "+str(numero2_rango_edad)+"): "+str(no_pob_reg_orinoquia_entre_rangoedad))
    print("Cantidad de población en región pacífico entre rango de edad ("+str(numero1_rango_edad)+" - "+str(numero2_rango_edad)+"): "+str(no_pob_reg_pacifico_entre_rangoedad))
    print("")
    cantidad_becas_a_entregar_ramazonia = int(input("Por favor ingrese la cantidad de becas a entregar en región amazonía entre 0 y "+str(no_pob_reg_amazonia_entre_rangoedad)+": "))
    cantidad_becas_a_entregar_randina = int(input("Por favor ingrese la cantidad de becas a entregar en región andina entre 0 y "+str(no_pob_reg_andina_entre_rangoedad)+": "))
    cantidad_becas_a_entregar_rcaribe = int(input("Por favor ingrese la cantidad de becas a entregar en región caribe entre 0 y "+str(no_pob_reg_caribe_entre_rangoedad)+": "))
    cantidad_becas_a_entregar_rorinoquia = int(input("Por favor ingrese la cantidad de becas a entregar en región orinoquia entre 0 y "+str(no_pob_reg_orinoquia_entre_rangoedad)+": "))
    cantidad_becas_a_entregar_rpacifico = int(input("Por favor ingrese la cantidad de becas a entregar en región pacífico entre 0 y "+str(no_pob_reg_pacifico_entre_rangoedad)+": "))
    print("")
    print("Becas a entregar en región Amazonia: "+str(cantidad_becas_a_entregar_ramazonia))
    print("Becas a entregar en región Andina: "+str(cantidad_becas_a_entregar_randina))
    print("Becas a entregar en región Caribe: "+str(cantidad_becas_a_entregar_rcaribe))
    print("Becas a entregar en región Orinoquia: "+str(cantidad_becas_a_entregar_rorinoquia))
    print("Becas a entregar en región Pacífico: "+str(cantidad_becas_a_entregar_rpacifico))
    print("")
    print("No. total becas a entregar: "+str(cantidad_becas_a_entregar_ramazonia + cantidad_becas_a_entregar_randina + cantidad_becas_a_entregar_rcaribe + cantidad_becas_a_entregar_rorinoquia + cantidad_becas_a_entregar_rpacifico))
    print("")
    
    becas_agotadas = False  

    becas_entregadas_ramazonia = 0
    becas_entregadas_randina = 0
    becas_entregadas_rcaribe = 0
    becas_entregadas_rorinoquia = 0
    becas_entregadas_rpacifico = 0
    
    no_becas_entregar_ramazonia = cantidad_becas_a_entregar_ramazonia
    no_becas_entregar_randina = cantidad_becas_a_entregar_randina
    no_becas_entregar_rcaribe = cantidad_becas_a_entregar_rcaribe
    no_becas_entregar_rorinoquia = cantidad_becas_a_entregar_rorinoquia
    no_becas_entregar_rpacifico = cantidad_becas_a_entregar_rpacifico
    
    becas_disponibles_ramazonia = no_becas_entregar_ramazonia - becas_entregadas_ramazonia
    becas_disponibles_randina = no_becas_entregar_randina - becas_entregadas_randina
    becas_disponibles_rcaribe = no_becas_entregar_rcaribe - becas_entregadas_rcaribe
    becas_disponibles_rorinoquia = no_becas_entregar_rorinoquia - becas_entregadas_rorinoquia
    becas_disponibles_rpacifico = no_becas_entregar_rpacifico - becas_entregadas_rpacifico
    iterador = 0
    
    while becas_agotadas == False:
        
        #Región Amazonía
        if (df_datos.iloc[iterador,6]  == 'Amazonia') and (becas_disponibles_ramazonia > 0) and (df_datos.iloc[iterador,8] == 'NO') and (numero1_rango_edad <= int(df_datos.iloc[iterador,1])) and (int(df_datos.iloc[iterador,1]) <= numero2_rango_edad):
            df_datos.iloc[iterador,8] = 'SI'
            becas_entregadas_ramazonia = becas_entregadas_ramazonia + 1
            becas_disponibles_ramazonia = no_becas_entregar_ramazonia - becas_entregadas_ramazonia
            
        if (becas_disponibles_ramazonia == 0) and (becas_disponibles_randina == 0) and (becas_disponibles_rcaribe == 0) and (becas_disponibles_rorinoquia == 0) and (becas_disponibles_rpacifico == 0):
            becas_agotadas = True
        
        iterador = iterador + 1
        if (iterador == len(df_datos)-1):
            iterador = 0
            
        #Región Andina
        if (df_datos.iloc[iterador,6]  == 'Andina') and (becas_disponibles_randina > 0) and (df_datos.iloc[iterador,8] == 'NO') and (numero1_rango_edad <= int(df_datos.iloc[iterador,1])) and (int(df_datos.iloc[iterador,1]) <= numero2_rango_edad):
            df_datos.iloc[iterador,8] = 'SI'
            becas_entregadas_randina = becas_entregadas_randina + 1
            becas_disponibles_randina = no_becas_entregar_randina - becas_entregadas_randina
            
        if (becas_disponibles_ramazonia == 0) and (becas_disponibles_randina == 0) and (becas_disponibles_rcaribe == 0) and (becas_disponibles_rorinoquia == 0) and (becas_disponibles_rpacifico == 0):
            becas_agotadas = True
        
        iterador = iterador + 1
        if (iterador == len(df_datos)-1):
            iterador = 0
            
        #Región Caribe
        if (df_datos.iloc[iterador,6]  == 'Caribe') and (becas_disponibles_rcaribe > 0) and (df_datos.iloc[iterador,8] == 'NO') and (numero1_rango_edad <= int(df_datos.iloc[iterador,1])) and (int(df_datos.iloc[iterador,1]) <= numero2_rango_edad):
            df_datos.iloc[iterador,8] = 'SI'
            becas_entregadas_rcaribe = becas_entregadas_rcaribe + 1
            becas_disponibles_rcaribe = no_becas_entregar_rcaribe - becas_entregadas_rcaribe
            
        if (becas_disponibles_ramazonia == 0) and (becas_disponibles_randina == 0) and (becas_disponibles_rcaribe == 0) and (becas_disponibles_rorinoquia == 0) and (becas_disponibles_rpacifico == 0):
            becas_agotadas = True
        
        iterador = iterador + 1
        if (iterador == len(df_datos)-1):
            iterador = 0
            
        #Región Orinoquia
        if (df_datos.iloc[iterador,6]  == 'Orinoquia') and (becas_disponibles_rorinoquia > 0) and (df_datos.iloc[iterador,8] == 'NO') and (numero1_rango_edad <= int(df_datos.iloc[iterador,1])) and (int(df_datos.iloc[iterador,1]) <= numero2_rango_edad):
            df_datos.iloc[iterador,8] = 'SI'
            becas_entregadas_rorinoquia = becas_entregadas_rorinoquia + 1
            becas_disponibles_rorinoquia = no_becas_entregar_rorinoquia - becas_entregadas_rorinoquia
            
        if (becas_disponibles_ramazonia == 0) and (becas_disponibles_randina == 0) and (becas_disponibles_rcaribe == 0) and (becas_disponibles_rorinoquia == 0) and (becas_disponibles_rpacifico == 0):
            becas_agotadas = True
        
        iterador = iterador + 1
        if (iterador == len(df_datos)-1):
            iterador = 0
            
        #Región Pacífico
        if (df_datos.iloc[iterador,6]  == 'Pacifica') and (becas_disponibles_rpacifico > 0) and (df_datos.iloc[iterador,8] == 'NO') and (numero1_rango_edad <= int(df_datos.iloc[iterador,1])) and (int(df_datos.iloc[iterador,1]) <= numero2_rango_edad):
            df_datos.iloc[iterador,8] = 'SI'
            becas_entregadas_rpacifico = becas_entregadas_rpacifico + 1
            becas_disponibles_rpacifico = no_becas_entregar_rpacifico - becas_entregadas_rpacifico
            
        if (becas_disponibles_ramazonia == 0) and (becas_disponibles_randina == 0) and (becas_disponibles_rcaribe == 0) and (becas_disponibles_rorinoquia == 0) and (becas_disponibles_rpacifico == 0):
            becas_agotadas = True
        
        iterador = iterador + 1
        if (iterador == len(df_datos)-1):
            iterador = 0
          
    print("")
    print("Becas entregadas región Amazonia: "+str(becas_entregadas_ramazonia))
    print("Becas entregadas región Andina: "+str(becas_entregadas_randina))
    print("Becas entregadas región Caribe: "+str(becas_entregadas_rcaribe))
    print("Becas entregadas región Orinoquia: "+str(becas_entregadas_rorinoquia))
    print("Becas entregadas región Pacífico: "+str(becas_entregadas_rpacifico))
    print("")
    becas_total_entregadas = becas_entregadas_ramazonia + becas_entregadas_randina + becas_entregadas_rcaribe + no_becas_entregar_rorinoquia + becas_entregadas_rpacifico
    print("Becas total entregadas: "+str(becas_total_entregadas))
    print("")

    frecuencia_por_region_pr = [becas_entregadas_ramazonia,becas_entregadas_randina,becas_entregadas_rcaribe,becas_entregadas_rorinoquia,becas_entregadas_rpacifico]

    poblacion_gmasculino_con_beca = df_datos['Beca asignada'][(df_datos['Beca asignada'] == 'SI') & (df_datos['genero'] == 'masculino')].count()
    poblacion_gfemenino_con_beca = df_datos['Beca asignada'][(df_datos['Beca asignada'] == 'SI') & ((df_datos['genero'] == 'femenino'))].count()
    poblacion_otrogenero_con_beca = df_datos['Beca asignada'][(df_datos['Beca asignada'] == 'SI') & ((df_datos['genero'] != 'masculino')) & (df_datos['genero'] != 'femenino')].count()
    frecuencia_por_genero = [poblacion_gmasculino_con_beca,poblacion_gfemenino_con_beca,poblacion_otrogenero_con_beca]
    
    poblacion_estrato1_con_beca_pr = df_datos['Beca asignada'][(df_datos['Beca asignada'] == 'SI') & (df_datos['estrato'] == '1')].count()
    poblacion_estrato2_con_beca_pr = df_datos['Beca asignada'][(df_datos['Beca asignada'] == 'SI') & (df_datos['estrato'] == '2')].count()
    poblacion_estrato3_con_beca_pr = df_datos['Beca asignada'][(df_datos['Beca asignada'] == 'SI') & (df_datos['estrato'] == '3')].count()
    poblacion_estrato4_con_beca_pr = df_datos['Beca asignada'][(df_datos['Beca asignada'] == 'SI') & (df_datos['estrato'] == '4')].count()
    poblacion_estrato5_con_beca_pr = df_datos['Beca asignada'][(df_datos['Beca asignada'] == 'SI') & (df_datos['estrato'] == '5')].count()
    frecuencia_por_edad_pr = [poblacion_estrato1_con_beca_pr,poblacion_estrato2_con_beca_pr,poblacion_estrato3_con_beca_pr,poblacion_estrato4_con_beca_pr,poblacion_estrato5_con_beca_pr]
    
    return frecuencia_por_genero,frecuencia_por_edad_pr,frecuencia_por_region_pr

datos_programa_por_region = Ejecutar_programa_por_region()

import numpy as np

print("Gráfico géneros Programa por género vs Programa por regiones: ")
print("")
print(datos_programa_por_genero[0])
print(datos_programa_por_region[0])
print("")
etiquetas_generos = ['Masculino','Femenino','Otro género']
numero_de_grupos = len(etiquetas_generos)
indice_barras = np.arange(numero_de_grupos)
ancho_barras = 0.35
plt.bar(indice_barras, datos_programa_por_genero[0], width=ancho_barras, label="Frec. género - programa por género")
plt.bar(indice_barras + ancho_barras, datos_programa_por_region[0], width=ancho_barras, label="Frec. género - programa por región")
plt.legend(loc = 'best')
plt.xticks(indice_barras+ancho_barras,etiquetas_generos)
plt.ylabel('Frecuencia')
plt.xlabel('Géneros')
plt.title('Frecuencia por géneros')
plt.show()
print("")

print("Gráfico estratos Programa por género vs Programa por regiones: ")
print("")
print(datos_programa_por_genero[1])
print(datos_programa_por_region[1])
print("")
etiquetas_estratos = ['Estrato 1','Estrato 2','Estrato 3','Estrato 4','Estrato 5']
numero_de_grupos = len(etiquetas_estratos)
indice_barras = np.arange(numero_de_grupos)
ancho_barras = 0.35
plt.bar(indice_barras, datos_programa_por_genero[1], width=ancho_barras, label="Frec. estratos - programa por género")
plt.bar(indice_barras + ancho_barras, datos_programa_por_region[1], width=ancho_barras, label="Frec. estratos - programa por región")
plt.legend(loc = 'best')
plt.xticks(indice_barras+ancho_barras,etiquetas_estratos)
plt.ylabel('Frecuencia')
plt.xlabel('Estratos')
plt.title('Frecuencia por estratos')
plt.show()
print("")

print("Gráfico regiones Programa por género vs Programa por regiones: ")
print("")
print(datos_programa_por_genero[2])
print(datos_programa_por_region[2])
print("")
etiquetas_regiones = ['Amazonía','Andina','Caribe','Orinoquía','Pacífico']
numero_de_grupos = len(etiquetas_regiones)
indice_barras = np.arange(numero_de_grupos)
ancho_barras = 0.35
plt.bar(indice_barras, datos_programa_por_genero[2], width=ancho_barras, label="Frec. regiones - programa por género")
plt.bar(indice_barras + ancho_barras, datos_programa_por_region[2], width=ancho_barras, label="Frec. regiones - programa por región")
plt.legend(loc = 'best')
plt.xticks(indice_barras+ancho_barras,etiquetas_regiones)
plt.ylabel('Frecuencia')
plt.xlabel('Regiones')
plt.title('Frecuencia por regiones')
plt.show()
print("")

# %% [markdown]
# **Misión 9**
#
# Ejecutar el algoritmo desarrollado en la *Misión 7* sobre la política que sugieres proponer al comité. Explicar claramente tus conlusiones con el soporte de los resultados de la herramienta.

# %%
# código

#conclusion = 'La asignaciòn de becas a los mejores promedios por edad (jovenes menores de 30 años), genero (mujeres) y región (35% pacifico, 35% caribe, 10% amazonia, 15% orinoquia y 5% andina) permite al Comite consolidar su estrategia de Accion afirmativa, dada la posibilidad de orientar la selecciòn de estos beneficios en poblacion generalmente excluida de educaciòn de calidad y de las oportunidades de movilidad social y aumento de ingresos economicos.'

# %% [markdown]
# ## Referencias
# * Discriminación Positiva<br>
# https://es.wikipedia.org/wiki/Discriminaci%C3%B3n_positiva
# * Análisis de formulación del programa “Ser Pilo Paga”<br>
# https://repository.urosario.edu.co/handle/10336/12526
# * La acción afirmativa en la Universidad de los Andes: El caso del programa "Oportunidades para talentos nacionales"<br> http://www.scielo.org.co/scielo.php?script=sci_arttext&pid=S0123-885X2004000300005
# * Acción afirmativa y equidad: un análisis desde la propuesta de Thomas Nagel<br>
# http://www.scielo.org.mx/scielo.php?script=sci_arttext&pid=S2007-24062016000200049

# %% [markdown]
# ## Créditos

# %% [markdown]
# Camilo Gómez - 11/06/21<br>
# *Revisado*: 25/08/21
